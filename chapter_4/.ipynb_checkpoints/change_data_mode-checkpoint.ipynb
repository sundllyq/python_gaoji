# %%
import re

# %%
log=open('/var/log/install.log').read()

# %%
# Out:
# USER              PID  %CPU %MEM      VSZ    RSS   TT  STAT STARTED      TIME COMMAND
# liyingqi          566   2.3  2.7  4120352 223680   ??  Rs    8:31上午   3:45.72 /
# liyingqi          471   2.0  2.3  4978776 190664   ??  S     8:23上午   8:50.62 /
# root               76   1.1  0.1  2513392   8708   ??  Ss    8:18上午   0:07.34 /
# root               81   1.0  0.1  2496752   6216   ??  Ss    8:18上午   0:39.64 /
# liyingqi          768   0.8  3.5  3881204 295108   ??  S     9:24上午  39:25.71 /
# _windowserver     155   0.7  2.9  4396788 241516   ??  Ss    8:18上午  13:29.62 /
# liyingqi          357   0.7  1.3  1115820 105824   ??  S     8:22上午   3:04.67 /
# _hidd              99   0.6  0.1  2473656   5292   ??  Ss    8:18上午   2:28.57 /
# liyingqi          561   0.1  0.3  2507168  27944 s000  S+    8:31上午   0:26.19 /
# liyingqi          805   0.1 10.0  6258840 836448   ??  S     9:48上午  18:51.52 /
# liyingqi          377   0.1  0.1  2521980   7808   ??  S     8:22上午   0:07.32 /
# ...
